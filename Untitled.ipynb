# %%
from networks import get_network, get_network_stats, plot_grid_network, get_city_network
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
grid = np.load("10k_2periods.npy", allow_pickle = True)

# %%
G = get_network(grid)

# %%
plot_grid_network(G, node_size = 2)

# %%
get_network_stats(G)
# Out:
#    average_degree  average_clustering  transitivity   entropy  dead_ends  \
# 0        2.746761            0.100093      0.128075  1.801226   0.208205
#
#     ways_4  nodes
# 0  0.18831   6484

# %%
G = get_city_network("Kaunas, Lithuania")

# %%
node_ids = list(G.nodes())
list_ys = []
list_xs = []

for node_id in node_ids:
    y = G.nodes[node_id]["y"]
    x = G.nodes[node_id]["x"]
    list_ys.append(y)
    list_xs.append(x)

# %%
# lenght (in cells) of the fractal grid

# %%
lenght = 150
H, xedges, yedges = np.histogram2d(list_xs, list_ys, bins = lenght)

# %%
H = H.T

# %%
plt.figure(figsize = (5,5))
plt.imshow(H, interpolation='nearest', origin='lower')
# Out:
# (<matplotlib.image.AxesImage at 0x7fe2a97ed1c0>,)

# %%
threshold = 0
tmp = H > threshold

tmp = tmp.astype(int)

# %%
plt.figure(figsize = (5,5))
plt.imshow(tmp, interpolation='nearest', origin='lower')

# %%
H.shape
# Out:
# (150, 150)

# %%
def get_fractal_from_network(G, bins = 150, threshold = 0):
    """
    Takes a graph generated with get_city_network and return a binary
    2d grid representing the fractal of the city.
    bins - amount of cells in the grid (bins x bins),
    threshold - number of nodes that should fall into a cell in order 
    for the cell to have a value of 1
    """
    # get the list of node ids
    node_ids = list(G.nodes())
    list_ys = []
    list_xs = []
    # get coordinates of each node
    for node_id in node_ids:
        y = G.nodes[node_id]["y"]
        x = G.nodes[node_id]["x"]
        list_ys.append(y)
        list_xs.append(x)
    H, xedges, yedges = np.histogram2d(list_xs, list_ys, bins = bins)
    H = H.T
    H = H > threshold
    return H.astype(int)

# %%
H = get_fractal_from_network(G)

# %%
plt.figure(figsize = (5,5))
plt.imshow(tmp, interpolation='nearest', origin='lower')
